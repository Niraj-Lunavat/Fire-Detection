# %%
# !pip install ultralytics
import ultralytics
from IPython import display
display.clear_output()
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.202 🚀 Python-3.10.12 torch-2.0.0 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
# Setup complete ✅ (4 CPUs, 31.4 GB RAM, 5016.7/8062.4 GB disk)

# %%
from IPython.display import Image

# %%
from ultralytics import YOLO
model = YOLO('/kaggle/input/fd-weights/best (4).pt')
class_names=model.model.names
class_names[0] = "Alert, Fire detected!"
class_names[1] = 'Alert, smoke detected!'
model.model.names = class_names
model.model.names
# Out:
# {0: 'Alert, Fire detected!', 1: 'Alert, smoke detected!'}

# %%
result = model(source='/kaggle/input/fire-and-smoke-detection-dataset/fire-smoke-detection.v2-v2.yolov8/test/images',conf=0.5, iou=0.5, show_conf=False, save=True)
# Out:
# image 1/85 /kaggle/input/fire-and-smoke-detection-dataset/fire-smoke-detection.v2-v2.yolov8/test/images/image_108_jpg.rf.d51fd6d7c5e64fdc2464412c20657227.jpg: 640x640 (no detections), 16.1ms
# image 2/85 /kaggle/input/fire-and-smoke-detection-dataset/fire-smoke-detection.v2-v2.yolov8/test/images/image_10_jpg.rf.dc07fca974f159f1a846f5a8b012bd1c.jpg: 640x640 (no detections), 15.2ms
# image 3/85 /kaggle/input/fire-and-smoke-detection-dataset/fire-smoke-detection.v2-v2.yolov8/test/images/image_128_jpg.rf.876276213683135a0ebacee3150f132d.jpg: 640x640 1 Alert, Fire detected!, 15.1ms
# image 4/85 /kaggle/input/fire-and-smoke-detection-dataset/fire-smoke-detection.v2-v2.yolov8/test/images/image_148_jpg.rf.aef43e63791522e21bde6312ab2d83ab.jpg: 640x640 (no detections), 15.2ms
# image 5/85 /kaggle/input/fire-and-smoke-detection-dataset/fire-smoke-detection.v2-v2.yolov8/test/images/image_162_jpg.rf.f6948816232d3af6ae990f478dc54981.jpg: 640x640 1 Alert, Fire detected!, 15.2ms
# ...

# %%
Image(f'/kaggle/working/runs/detect/predict/image_442_jpg.rf.ed38e1215b55b4cf4acaad5e8cd6309a.jpg', width=500, height=500)
